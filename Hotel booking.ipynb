# %%
import numpy as np
import pandas as pd

# %%
data_hotel = pd.read_csv("E://Data Set//hotel_bookings.csv")
data_hotel.head(15)
# Out:
#            hotel  is_canceled  arrival_date_year arrival_date_month  \
# 0   Resort Hotel            0               2015               July
# 1   Resort Hotel            0               2015               July
# 2   Resort Hotel            0               2015               July
# 3   Resort Hotel            0               2015               July
# 4   Resort Hotel            0               2015               July
# 5   Resort Hotel            0               2015               July
# 6   Resort Hotel            0               2015               July
# 7   Resort Hotel            0               2015               July
# 8   Resort Hotel            1               2015               July
# 9   Resort Hotel            1               2015               July
# 10  Resort Hotel            1               2015               July
# 11  Resort Hotel            0               2015               July
# 12  Resort Hotel            0               2015               July
# ...

# %%
d1 = data_hotel.loc[data_hotel.reservation_status=='No-Show']
d1
# Out:
#               hotel  is_canceled  arrival_date_year arrival_date_month  \
# 122    Resort Hotel            1               2015               July
# 328    Resort Hotel            1               2015               July
# 343    Resort Hotel            1               2015               July
# 467    Resort Hotel            1               2015               July
# 472    Resort Hotel            1               2015               July
# ...             ...          ...                ...                ...
# 29537  Resort Hotel            1               2016            October
# 29694  Resort Hotel            1               2017            January
# 32349  Resort Hotel            1               2017           February
# 36837  Resort Hotel            1               2017                May
# 40034    City Hotel            1               2015             August
#
#        arrival_date_day_of_month  stays_in_weekend_nights  \
# ...

# %%
d2 = data_hotel.loc[data_hotel.reservation_status.isin(['No-Show'])]
d2
# Out:
#               hotel  is_canceled  arrival_date_year arrival_date_month  \
# 122    Resort Hotel            1               2015               July
# 328    Resort Hotel            1               2015               July
# 343    Resort Hotel            1               2015               July
# 467    Resort Hotel            1               2015               July
# 472    Resort Hotel            1               2015               July
# ...             ...          ...                ...                ...
# 29537  Resort Hotel            1               2016            October
# 29694  Resort Hotel            1               2017            January
# 32349  Resort Hotel            1               2017           February
# 36837  Resort Hotel            1               2017                May
# 40034    City Hotel            1               2015             August
#
#        arrival_date_day_of_month  stays_in_weekend_nights  \
# ...

# %%
data_hotel['is_canceled'].value_counts()
# Out:
# 0    28932
# 1    11128
# Name: is_canceled, dtype: int64

# %%
not_cancled_in_2017 = data_hotel[(data_hotel.is_canceled==0)&(data_hotel.arrival_date_year==2017)&(data_hotel.is_repeated_guest==1)]
not_cancled_in_2017['arrival_date_month'].value_counts()
# Out:
# January     145
# March       140
# February    128
# May          95
# April        79
# June         73
# August       50
# July         48
# Name: arrival_date_month, dtype: int64
